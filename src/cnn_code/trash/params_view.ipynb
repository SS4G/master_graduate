# %%
import h5py
import pandas as pd
import numpy as np

# %%
model_params = h5py.File("relu_GTSRB_model.h5", "r")

# %%
for k in model_params.keys():
    print(k)
# Out:
# model_weights
# optimizer_weights

# %%
list(model_params["model_weights"].items())
# Out:
# [('conv2d_1', <HDF5 group "/model_weights/conv2d_1" (1 members)>),
#  ('conv2d_2', <HDF5 group "/model_weights/conv2d_2" (1 members)>),
#  ('dense_1', <HDF5 group "/model_weights/dense_1" (1 members)>),
#  ('dense_2', <HDF5 group "/model_weights/dense_2" (1 members)>),
#  ('dense_3', <HDF5 group "/model_weights/dense_3" (1 members)>),
#  ('flatten_1', <HDF5 group "/model_weights/flatten_1" (0 members)>),
#  ('max_pooling2d_1',
#   <HDF5 group "/model_weights/max_pooling2d_1" (0 members)>),
#  ('max_pooling2d_2',
#   <HDF5 group "/model_weights/max_pooling2d_2" (0 members)>)]

# %%
list(model_params["model_weights"]["conv2d_2"].items())
# Out:
# [('conv2d_2', <HDF5 group "/model_weights/conv2d_2/conv2d_2" (2 members)>)]

# %%
list(model_params["model_weights"]["conv2d_2"]["conv2d_2"].items())
# Out:
# [('bias:0', <HDF5 dataset "bias:0": shape (16,), type "<f4">),
#  ('kernel:0', <HDF5 dataset "kernel:0": shape (5, 5, 6, 16), type "<f4">)]

# %%
list(model_params["model_weights"]["conv2d_2"]["conv2d_2"]["kernel:0"]) # 矩阵权重参数
# Out:
# [array([[[-5.88183291e-02,  5.66839390e-02,  6.57410398e-02,
#            8.52083340e-02, -7.25497976e-02,  9.84569117e-02,
#            1.03254072e-01,  8.99559185e-02,  1.09273382e-01,
#            1.21179104e-01,  1.04912855e-01,  7.08880350e-02,
#            9.61175933e-02, -6.68654591e-02,  1.25029802e-01,
#            5.82103133e-02],
#          [ 3.27058434e-02, -6.83178529e-02, -4.33022007e-02,
#            8.93158931e-03,  3.23382616e-02,  2.17869133e-02,
#           -1.13713935e-01, -4.29901667e-02,  1.66643962e-01,
#            2.20130272e-02, -2.05016389e-01,  6.52019456e-02,
#            9.05798823e-02,  1.16292223e-01,  3.98165360e-03,
#            1.11593321e-01],
#          [ 1.83257461e-01,  7.56419078e-02, -3.38828117e-02,
#           -5.39615415e-02, -6.35674596e-02,  1.57680705e-01,
#            1.29965693e-01,  4.08341959e-02,  7.94862434e-02,
#            1.72164246e-01,  1.33529767e-01, -8.55494216e-02,
# ...
